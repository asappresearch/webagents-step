# %%
import os
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from tabulate import tabulate

plt.rcParams['font.size'] = 18

# %%
import pandas as pd

# Define the data
data = {
    "method": ["Miniwob", "CRM", "Liveweb"],
    "not_compressed": [182, 1367, 11485],
    "compressed": [182, 539, 1933]
}

# Create the DataFrame
df = pd.DataFrame(data)

# Display the DataFrame
print(df)
# Out:
#     method  not_compressed  compressed
# 0  Miniwob             182         182
# 1      CRM            1367         539
# 2  Liveweb           11485        1933

# %%
# Create the DataFrame
df = pd.DataFrame(data)

# Set the colors
colors = ['skyblue', 'lightcoral']

plt.figure(figsize=(10, 6))

# Plot the data
ax = df.plot(x="method", kind="bar", color=colors, width=0.7)
# plt.title("Comparison of Compressed v/s Not Compressed")
plt.ylabel("Tokens")
plt.xlabel("Tasks")
plt.xticks(rotation=0)
plt.tight_layout()
plt.legend(loc='upper left')

# Display the plot
plt.show()
